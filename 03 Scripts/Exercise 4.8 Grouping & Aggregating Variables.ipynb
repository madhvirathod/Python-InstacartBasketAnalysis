# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 1. Import ords_prods_merge_derived Dataframe

# %%
import pandas as pd

# %%
path=r"C:\Users\tjsra\OneDrive\Desktop\INSTACART BASKET ANALYSIS"

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_derived.pkl'))

# %% [markdown]
# ### Check dimensions of imported dataframe for consistency

# %%
ords_prods_merge.shape
# Out:
# (9918253, 19)

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                  6                 11
# 1   1977647      138            30                  6                 17
# 2    389851      709             2                  0                 21
# 3    652770      764             1                  3                 13
# 4   1813452      764             3                  4                 17
#
# ...

# %% [markdown]
# ## 2. Calculate Mean of Order Number

# %%
ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.393473
# 2     17.000546
# 3     17.216578
# 4     17.714601
# 5     14.958409
# 6     16.454727
# 7     17.325861
# 8     15.117326
# 9     16.027829
# 10    20.229811
# 11    16.453444
# 12    15.895358
# 13    16.692698
# 14    16.817133
# 15    16.133323
# 16    17.607401
# 17    15.936598
# 18    19.646685
# 19    17.216008
# 20    16.393918
# 21    22.580576
# Name: order_number, dtype: float64

# %% [markdown]
# ## 3. Analyze the result:  1.Compared to the results from the subset, the entire dataframe includes all'deparment_id' values.2. the mean values for the department id present in the subset are changed. 3. some values are increased and others decreased.

# %% [markdown]
# ## 4. Creating a loyalty flag for existing customers.

# %% [markdown]
# ###  using trnsform() function

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\tjsra\AppData\Local\Temp\ipykernel_18984\1681540670.py:1: FutureWarning: The provided callable <function max at 0x000002825DD14540> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %% [markdown]
# ### View update dataframe.

# %%
ords_prods_merge.head(20)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %% [markdown]
# ### Use loc() function to make loyalty flag column with given criteria

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %% [markdown]
# ### Check frequency of values in new loyalty flag column

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    4865587
# Loyal customer      3154279
# New customer        1898387
# Name: count, dtype: int64

# %% [markdown]
# ### View updated data frame

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  ...  \
# 0   3139998      138            28                  6                 11  ...
# 1   1977647      138            30                  6                 17  ...
# 2    389851      709             2                  0                 21  ...
# 3    652770      764             1                  3                 13  ...
# 4   1813452      764             3                  4                 17  ...
#
# ...

# %% [markdown]
# ## 5. Look at Spendig Habits of Loyalty Groups.

# %% [markdown]
# ### Use groupby() & agg() to determine basic statistics of spending habits by loyalty group

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer     9.435027  1.0  99999.0
# New customer      12.705686  1.0  99999.0
# Regular customer  11.675800  1.0  99999.0

# %% [markdown]
# ### The average price of a product purchased by a new customer is more than that of loyal customer.

# %% [markdown]
# ## 6. Create a spending flag for each user based on the average price

# %% [markdown]
# ### Use trnsform() to determine the mean price of products purchased by each user

# %%
ords_prods_merge['mean_product_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\tjsra\AppData\Local\Temp\ipykernel_18984\72723565.py:1: FutureWarning: The provided callable <function mean at 0x000002825DD14F40> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['mean_product_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %% [markdown]
# ### View relevant columns

# %%
ords_prods_merge[['user_id', 'mean_product_price']].head(20)
# Out:
#     user_id  mean_product_price
# 0       138            6.935811
# 1       138            6.935811
# 2       709            7.930208
# 3       764            4.972414
# 4       764            4.972414
# 5       777            6.935398
# 6       825            5.957576
# 7       910            6.680000
# 8      1052            7.162500
# 9      1052            7.162500
# 10     1379            5.813636
# 11     1480            5.081633
# 12     1480            5.081633
# 13     1480            5.081633
# 14     1494            6.803797
# 15     1494            6.803797
# 16     1494            6.803797
# 17     1540            6.607122
# 18     1540            6.607122
# 19     1540            6.607122

# %% [markdown]
# ### Create spending flag column with given criteria using loc() function

# %%
ords_prods_merge.loc[ords_prods_merge['mean_product_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_product_price'] < 10, 'spending_flag'] = 'Low spender'

# %% [markdown]
# ### check frequency of new spending flag column

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     9736335
# High spender     181918
# Name: count, dtype: int64

# %% [markdown]
# ### View relevant columns of updated data frame

# %%
ords_prods_merge[['user_id', 'mean_product_price', 'spending_flag']].head(20)
# Out:
#     user_id  mean_product_price spending_flag
# 0       138            6.935811   Low spender
# 1       138            6.935811   Low spender
# 2       709            7.930208   Low spender
# 3       764            4.972414   Low spender
# 4       764            4.972414   Low spender
# 5       777            6.935398   Low spender
# 6       825            5.957576   Low spender
# 7       910            6.680000   Low spender
# 8      1052            7.162500   Low spender
# 9      1052            7.162500   Low spender
# 10     1379            5.813636   Low spender
# 11     1480            5.081633   Low spender
# 12     1480            5.081633   Low spender
# 13     1480            5.081633   Low spender
# 14     1494            6.803797   Low spender
# 15     1494            6.803797   Low spender
# 16     1494            6.803797   Low spender
# 17     1540            6.607122   Low spender
# 18     1540            6.607122   Low spender
# ...

# %% [markdown]
# ## 7 Create an order frequency flag that marks the regularity of a user's ordering behaviour according to the median in the 'days_since_last_order' column.

# %% [markdown]
# ### Use groupby and tranform to determine median number of days between orders for each user

# %%
ords_prods_merge['median_days_between_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform(np.median)
# Out:
# C:\Users\tjsra\AppData\Local\Temp\ipykernel_18984\2532972549.py:1: FutureWarning: The provided callable <function median at 0x000002825DE50D60> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['median_days_between_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform(np.median)

# %% [markdown]
# ### View relevant columns of updated dataframe

# %%
ords_prods_merge[['user_id', 'days_since_last_order', 'median_days_between_orders']].head(20)
# Out:
#     user_id  days_since_last_order  median_days_between_orders
# 0       138                    3.0                         8.0
# 1       138                   20.0                         8.0
# 2       709                    6.0                         8.0
# 3       764                    NaN                         9.0
# 4       764                    9.0                         9.0
# 5       777                   26.0                        11.0
# 6       825                   30.0                        20.0
# 7       910                   30.0                         6.0
# 8      1052                   19.0                        10.0
# 9      1052                   15.0                        10.0
# 10     1379                    NaN                        20.0
# 11     1480                    7.0                         7.0
# 12     1480                    7.0                         7.0
# 13     1480                   12.0                         7.0
# ...

# %% [markdown]
# ### Create order frequency flag based on given criteria using loc() function.

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] > 20, 'order_frequency'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days_between_orders'] <= 20) & (ords_prods_merge['median_days_between_orders'] > 10), 'order_frequency'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] <= 10, 'order_frequency'] = 'Frequent customer'

# %% [markdown]
# ###  Check value counts of new order_frequency column

# %%
ords_prods_merge['order_frequency'].value_counts(dropna = False)
# Out:
# order_frequency
# Frequent customer        6582166
# Regular customer         2226335
# Non-frequent customer    1109752
# Name: count, dtype: int64

# %% [markdown]
# ### View relevant columns of updated data frame.

# %%
ords_prods_merge[['user_id', 'days_since_last_order', 'median_days_between_orders', 'order_frequency']].head(25)
# Out:
#     user_id  days_since_last_order  median_days_between_orders  \
# 0       138                    3.0                         8.0
# 1       138                   20.0                         8.0
# 2       709                    6.0                         8.0
# 3       764                    NaN                         9.0
# 4       764                    9.0                         9.0
# 5       777                   26.0                        11.0
# 6       825                   30.0                        20.0
# 7       910                   30.0                         6.0
# 8      1052                   19.0                        10.0
# 9      1052                   15.0                        10.0
# 10     1379                    NaN                        20.0
# 11     1480                    7.0                         7.0
# 12     1480                    7.0                         7.0
# 13     1480                   12.0                         7.0
# ...

# %%
ords_prods_merge['prices'].describe()
# Out:
# count    9.918253e+06
# mean     1.116030e+01
# std      4.168003e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64

# %%
ords_prods_merge['prices'].mean()
# Out:
# 11.160295709335092

# %%
ords_prods_merge['prices'].median()
# Out:
# 7.4

# %%
ords_prods_merge['prices'].max()
# Out:
# 99999.0

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 100]
# Out:
#          product_id                      product_name  aisle_id  \
# 4010767       21553  Lowfat 2% Milkfat Cottage Cheese       108
# 4010768       21553  Lowfat 2% Milkfat Cottage Cheese       108
# 4010769       21553  Lowfat 2% Milkfat Cottage Cheese       108
# 4010770       21553  Lowfat 2% Milkfat Cottage Cheese       108
# 4010771       21553  Lowfat 2% Milkfat Cottage Cheese       108
# ...             ...                               ...       ...
# 6670867       33664             2 % Reduced Fat  Milk        84
# 6670868       33664             2 % Reduced Fat  Milk        84
# 6670869       33664             2 % Reduced Fat  Milk        84
# 6670870       33664             2 % Reduced Fat  Milk        84
# 6670871       33664             2 % Reduced Fat  Milk        84
#
#          department_id   prices  order_id  user_id  order_number  \
# 4010767             16  14900.0    912404       17            12
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan

# %%
ords_prods_merge['prices'].max()
# Out:
# 25.0

# %% [markdown]
# ## 8 Exporting Data

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_grouped.pkl'))
