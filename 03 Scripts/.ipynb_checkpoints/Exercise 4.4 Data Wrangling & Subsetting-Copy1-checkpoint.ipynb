# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Data.  Orders.csv    Products.csv    departments.csv

# %%
import pandas as pd

# %%
path=r"C:\Users\tjsra\OneDrive\Desktop\INSTACART BASKET ANALYSIS"

# %%
df_ords= pd.read_csv(os.path.join(path, '02 Data', 'original Data', 'Orders.csv'), index_col=False)

# %%
df_prods=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'Products.csv'),index_col=False)

# %%
df_dep= pd.read_csv(os.path.join(path, '02 Data', 'original Data', 'departments.csv'), index_col=False)

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ### Dropping eval_set column from orders.csv

# %%
df_ords.drop(columns=['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 1048570   1805240    63100             1          0                 11
# 1048571   2719402    63100             2          0                  8
# 1048572   2855250    63100             3          2                 13
# 1048573   2355832    63100             4          5                 16
# 1048574   2362552    63100             5          1                 13
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %% [markdown]
# ###  print all functions within the 'days_since_prior_order' column (find out missing values)

# %%
df_ords['days_since_prior_order'].value_counts(dropna=False)
# Out:
# days_since_prior_order
# 30.0    112498
# 7.0      98756
# 6.0      73424
# 4.0      67774
# 3.0      66728
# 5.0      65969
# NaN      63100
# 2.0      59256
# 8.0      55759
# 1.0      44010
# 9.0      36115
# 14.0     30802
# 10.0     29562
# 13.0     25552
# 11.0     24763
# 12.0     23600
# 0.0      20627
# 15.0     20620
# 16.0     14487
# 21.0     13829
# 17.0     12048
# 20.0     11722
# 18.0     11047
# 19.0     10682
# 22.0      9787
# 28.0      7999
# 23.0      7282
# 27.0      6770
# 24.0      6362
# 25.0      5943
# 26.0      5883
# 29.0      5819
# Name: count, dtype: int64

# %% [markdown]
# ### Rename 'order_dow' column

# %%
df_ords.rename(columns = {'order_dow' : 'order_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_day_of_week  \
# 0   2539329        1    prior             1                  2
# 1   2398795        1    prior             2                  3
# 2    473747        1    prior             3                  3
# 3   2254736        1    prior             4                  4
# 4    431534        1    prior             5                  4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %% [markdown]
# ###  changing data type of the column 'order_id' to string from orders.csv

# %%
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ### Transposing df_dep  (wide to long)

# %%
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# ### Creating a new transposed df_dep dataframe

# %%
df_dep_t = df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# ###  Creating an index for df_dep_t dataframe

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %% [markdown]
# ### creating a header with the first row of the df_dep_t dataframe

# %%
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %% [markdown]
# ### Take the the data under the header row for a new df

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %% [markdown]
# ### set the header row as the df header

# %%
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# # Creating a Data Dictionary

# %% [markdown]
# ### creating Data Dictionary for df_dep_t_new which presents the each department for their particular iteams

# %%
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# ### checking the data dictionary for what department 19 represent

# %%
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %% [markdown]
# # Subsetting

# %% [markdown]
# ### creating a df_snacks dataframe with only product with 'department_id' of 19

# %%
df_snacks =  df_prods[df_prods['department_id']==19]

# %%
df_snacks
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %% [markdown]
# ## find another identifier variable in the df_ords dataframe that doesn't need to be included in your analysis as a numeric variable and change it to a suitable format

# %% [markdown]
# ### changing 'user_id' column to string

# %%
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
df_ords['user_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## Look for a variable in your df_ords dataframe with an unintuitive name and change its name without overwriting the dataframe

# %% [markdown]
# ### Rename 'days_since_prior_order' from df_ords

# %%
df_ords.head()
# Out:
#   order_id user_id eval_set  order_number  order_day_of_week  \
# 0  2539329       1    prior             1                  2
# 1  2398795       1    prior             2                  3
# 2   473747       1    prior             3                  3
# 3  2254736       1    prior             4                  4
# 4   431534       1    prior             5                  4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_ords.rename(columns = {'days_since_prior_order' : 'days_since_last_order'}, inplace = True)

# %%
df_ords
# Out:
#         order_id user_id eval_set  order_number  order_day_of_week  \
# 0        2539329       1    prior             1                  2
# 1        2398795       1    prior             2                  3
# 2         473747       1    prior             3                  3
# 3        2254736       1    prior             4                  4
# 4         431534       1    prior             5                  4
# ...          ...     ...      ...           ...                ...
# 1048570  1805240   63100    prior             1                  0
# 1048571  2719402   63100    prior             2                  0
# 1048572  2855250   63100    prior             3                  2
# 1048573  2355832   63100    prior             4                  5
# 1048574  2362552   63100    train             5                  1
#
#          order_hour_of_day  days_since_last_order
# 0                        8                    NaN
# 1                        7                   15.0
# ...

# %% [markdown]
# ##  Your client wants to know what the busiest hour is for placing orders.find the frequency of the corresponding variable and share your findings. The busiest hour for placing order is 10am

# %%
df_ords['order_hour_of_day'].value_counts()
# Out:
# order_hour_of_day
# 10    88228
# 11    87087
# 14    86905
# 15    86888
# 13    85652
# 12    84204
# 16    83421
# 9     78737
# 17    69960
# 18    56284
# 8     54868
# 19    43076
# 20    31735
# 7     28199
# 21    23972
# 22    18824
# 23    12112
# 6      9253
# 0      6881
# 1      3698
# 5      2882
# 2      2312
# 4      1748
# 3      1649
# Name: count, dtype: int64

# %% [markdown]
# ## Determine the meaning behind a value of 4 in the 'department_id' column within the df_prods dataframe using a data dictionary.  department 4 is for produce.

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# ## The sales team in your client's organization wants to know more about breakfast iteam sales. create a subset containing only the required information

# %% [markdown]
# ### checking with the department -'Breakfast'

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %% [markdown]
# ### create a df_breakfast dataframe with only product with 'department_id' of 14

# %%
df_breakfast =  df_prods[df_prods['department_id']==14]

# %%
df_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
df_breakfast['department_id'].value_counts()
# Out:
# department_id
# 14    1116
# Name: count, dtype: int64

# %% [markdown]
# ## They'd also like to see details about products that customers might use to throw dinner parties. your task is to find all observations from the entire dataframe that include iteams from the following departments: alcohol, deli, beverages, and meat/seafood. You'll need to present this subset to your client.

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %% [markdown]
# ### create df_dinner_parties dataframe with product with department_id of 5-alcohol,7-beverages,12-meat/seafood,20-deli.

# %%
df_dinner_parties = df_prods[df_prods['department_id'].isin([5,7,12,20])]

# %%
df_dinner_parties.head(15)
# Out:
#     product_id                                       product_name  aisle_id  \
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 6            7                     Pure Coconut Water With Orange        98
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# 16          17                                  Rendered Duck Fat        35
# 19          20     Pomegranate Cranberry & Aloe Vera Enrich Drink        98
# 22          23                             Organic Turkey Burgers        49
# 34          35     Italian Herb Porcini Mushrooms Chicken Sausage       106
# 38          39           Daily Tangerine Citrus Flavored Beverage        64
# 39          40  Beef Hot Links Beef Smoked Sausage With Chile ...       106
# 43          44                        Sparkling Raspberry Seltzer       115
# ...

# %%
df_dinner_parties['department_id'].value_counts()
# Out:
# department_id
# 7     4365
# 20    1322
# 5     1056
# 12     907
# Name: count, dtype: int64

# %% [markdown]
# ## How many rows does the last dataframe you created have?

# %%
df_dinner_parties.shape
# Out:
# (7650, 5)

# %% [markdown]
# ## someone from the data engineers team in Instacart thinks they have spotted something strange about the customer with a 'user_id' of '1'. Extract all the information you can about this user.

# %% [markdown]
# ### create a df_user_1 dataframe with user_id of 1

# %%
df_user_1 = df_ords[df_ords['user_id']=='1']

# %%
df_user_1
# Out:
#    order_id user_id eval_set  order_number  order_day_of_week  \
# 0   2539329       1    prior             1                  2
# 1   2398795       1    prior             2                  3
# 2    473747       1    prior             3                  3
# 3   2254736       1    prior             4                  4
# 4    431534       1    prior             5                  4
# 5   3367565       1    prior             6                  2
# 6    550135       1    prior             7                  1
# 7   3108588       1    prior             8                  1
# 8   2295261       1    prior             9                  1
# 9   2550362       1    prior            10                  4
# 10  1187899       1    train            11                  4
#
#     order_hour_of_day  days_since_last_order
# 0                   8                    NaN
# 1                   7                   15.0
# 2                  12                   21.0
# ...

# %% [markdown]
# ## you also need to provide some details about this user's behaviour. what basic stats can you provide based on the information you have?

# %%
df_user_1.describe()
# Out:
#        order_number  order_day_of_week  order_hour_of_day  \
# count     11.000000          11.000000          11.000000
# mean       6.000000           2.636364          10.090909
# std        3.316625           1.286291           3.477198
# min        1.000000           1.000000           7.000000
# 25%        3.500000           1.500000           7.500000
# 50%        6.000000           3.000000           8.000000
# 75%        8.500000           4.000000          13.000000
# max       11.000000           4.000000          16.000000
#
#        days_since_last_order
# count              10.000000
# mean               19.000000
# std                 9.030811
# min                 0.000000
# 25%                14.250000
# 50%                19.500000
# 75%                26.250000
# max                30.000000

# %% [markdown]
# # Export df_ords dataframe as 'orders_wrangled.csv' in 'prepared Data' folder

# %%
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %%
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))
